# %% [markdown]
# # <font color='12284A' style="font-family: andale mono, monospace; font-size: 28px; text-transform: uppercase">Drum Audio Sample Classifier - Model<font><a class='anchor' id='top'></a>
# This portion of the application is used to create the model. It imports, and parses the dataset, creates and fits the model, and finally saves the model to be used by the "drum_prediction" jupyter notebook.
#
# I would like the recognize and thank Dr. Papia Nandi for her article "CNNs for Audio Classification". Citation comments are included in code snippets directly adapted from her work and proper citations will be included in Task documentation.

# %%
#Imports Modules
import matplotlib.pyplot as plt
import pandas as pd
import os
import librosa
from sklearn.preprocessing import normalize
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras import models, layers
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")

# %%
# Get acbsolute path of project
abs_path = os.getcwd()

# Imports csv of dataset metadata
df = pd.read_csv(abs_path + "/dataset/samples_metadata.csv")

# Defines variables that may be changes in the future

# Number of spectrogram frames to use
LENGTH = 100

# Drum Type Dictionary with indices
drum_types = {
    'clap': 0,
    'closedhat': 1,
    'kick': 2,
    'openhat': 3,
    'snare': 4,
}

# %%
# Converts Audio Samples in single Numpy Array to train model

# Gets relative path to audio samples for dataset
samples = abs_path + "/dataset/samples/"

# Create blank lists to fill
samples_data = []
samples_visual_data = []
samples_data_type = []

for sample in sorted(os.listdir(samples)):
    # Blank arrays of zeros to be overwritten by sample data, required to make all sample arrays the same size
    # Array Dimensions are as follows: D1: Pitch Slices (128), D2: Time samples (LENGTH), and D3: value of power/amplitude
    # D3 is duplicated across 3 values in the model version since CNNs were made with RGB (3) image values in mind. It's
    # simpler to make the CNN Model think it is a RGB image than try and make it work for audio specifically
    sample_array = np.zeros((128, LENGTH, 3))
    visual_array = np.zeros((128, LENGTH))
    
    # Load, Trim, and resample the audio file
    audio, sr = librosa.load(samples+sample, sr=22050)
    audio, _ = librosa.effects.trim(audio, top_db=50)
    audio = librosa.resample(y=audio, orig_sr=sr, target_sr=22050)
    
    # Compute mel spectrogram
    melspect = librosa.feature.melspectrogram(y=audio, sr=22050, n_mels=128)
    # Store how many frames this sample uses, capped at LENGTH
    t = min(melspect.shape[1], LENGTH)
    # Store raw power in the visual array
    visual_array[:, :t] = melspect
    # Convert to db
    melspect = librosa.power_to_db(melspect, ref=np.max)
    # Store db values in sample array
    sample_array[:, :t, :] = np.repeat(melspect[:, :t, np.newaxis], 3, axis=2)
    
    # Adds audio samples data to the list of samples_data, and samples_visual_data
    samples_data.append(sample_array)
    samples_visual_data.append(visual_array)
    
    # Adds audio samples type of drum to samples_data_type
    samples_data_type.append([val for key,val in drum_types.items() if key in sample])

# Convert Lists to Numpy Arrays
samples_data = np.array(samples_data)
samples_visual_data = np.array(samples_visual_data)
samples_data_type = np.array(samples_data_type)

# %% [markdown]
# This is our preprocessing step. Anything we do here must be replicated exactly when we want to sample the final model. Except for the visuals related stuff, which is just for testing and sanity checking before we train the model.

# %%
# Outputs Waveform of the first of each Drum Type, conveys amplitude over time
for i, drum in enumerate(drum_types):
    y, sr = librosa.load(samples + drum + '_0001.wav')

    y,z = librosa.effects.trim(y, top_db=50)
    y = librosa.resample(y=y, orig_sr=sr, target_sr=22050)

    plt.figure(figsize=(8, 3))
    plt.suptitle("Figure " + str(i+1) + ": " + drum + '_0001.wav',x=0.5, y=0.915,fontsize=12)
    plt.xlabel("Time")
    plt.ylabel('Amplitude')
    
    plt.xticks(np.arange(0, 1, 1))
    plt.yticks(np.arange(-2, 2, 1))
    plt.tight_layout(pad=1.0)
    
    librosa.display.waveshow(y, sr=sr)

# %%
# Outputs Melspectrum of the All of each Drum Type, conveys pitch over time
values = [["Clap Samples", 0, 227],
          ["Closed Hat Samples", 227, 469],
          ["Kick Samples", 469, 1217], 
          ["Open Hat Samples", 1217, 1331],
          ["Snare Samples", 1331, 2746]]

for i, value_set in enumerate(values):
    a = samples_visual_data[value_set[1]:value_set[2]]
    y, z, x = np.nonzero(a > 10)

    fig, ax = plt.subplots(1, 1, figsize = (5, 5), subplot_kw={'projection': '3d'})

    ax.scatter3D(x, y, z, s=10, c=x, cmap='cividis')
    plt.title("Figure " + str(i+1) + ": " + value_set[0])
    plt.xlabel("Time")
    plt.ylabel('Audio File')
    ax.set_zlabel('Pitch')
    
plt.show()

# %%
# Split once to get the test and training set
X_train, X_test, y_train, y_test = train_test_split(samples_data, samples_data_type, test_size=0.25, random_state=123)

# Split twice to get the validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=123)

# %% [markdown]
# This splits the dataset into 3 sets: training (56%), validation (19%), and test (25%)

# %%
# Adapted from "CNNs for Audio Classification" by Papia Nandi, 2021

# Adds layers to model
# Conv2D Layers are important for CNNs to learn audio spacial information
# Max Pooling and Dropout Layers help avoid overfitting

def make_norm_layer(input_shape, input):
    norm_layer = layers.Normalization(input_shape=input_shape)
    # computes mean and variance from training set
    norm_layer.adapt(input)
    return norm_layer

model = models.Sequential()
model.add(make_norm_layer((128, LENGTH, 3), X_train))
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, LENGTH, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(len(drum_types), activation='softmax'))
# Out:
# 2025-11-28 16:07:06.034898: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-11-28 16:07:06.034988: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2025-11-28 16:07:06.035002: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2025-11-28 16:07:06.035026: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-11-28 16:07:06.035041: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# Normalization layer is included in the model so that normalization parameters are stored inside the model itself.
# BatchNormalization layers were added for stability, which seems to have helped a lot.

# %%
# Model is compiled. Adam is used to have a automatic learning rate
# Sparse Categorical Crossentropy is used since there are multiple drum types, but only one drum type per drum
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Fits model
history = model.fit(X_train, y_train, epochs=50, validation_data= (X_val, y_val))
# Out:
# Epoch 1/50
# 2025-11-28 16:07:07.145622: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.3912 - loss: 4.0315 - val_accuracy: 0.5087 - val_loss: 1.7792
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.4301 - loss: 4.7107 - val_accuracy: 0.4971 - val_loss: 1.9699
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.4670 - loss: 5.7385 - val_accuracy: 0.3165 - val_loss: 3.6381
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5402 - loss: 6.3717 - val_accuracy: 0.2660 - val_loss: 10.8916
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6114 - loss: 6.7263 - val_accuracy: 0.2932 - val_loss: 18.7118
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6509 - loss: 8.0187 - val_accuracy: 0.2913 - val_loss: 21.1601
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6898 - loss: 7.7458 - val_accuracy: 0.3573 - val_loss: 24.8098
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7209 - loss: 7.3293 - val_accuracy: 0.3845 - val_loss: 27.4167
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7396 - loss: 7.7402 - val_accuracy: 0.4078 - val_loss: 23.5703
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7124 - loss: 8.8184 - val_accuracy: 0.5417 - val_loss: 12.6147
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7571 - loss: 6.3889 - val_accuracy: 0.6718 - val_loss: 9.0247
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.7591 - loss: 6.2905 - val_accuracy: 0.7748 - val_loss: 4.6914
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7798 - loss: 6.2667 - val_accuracy: 0.8388 - val_loss: 3.2291
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.7999 - loss: 5.3767 - val_accuracy: 0.8718 - val_loss: 2.3950
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7791 - loss: 5.8594 - val_accuracy: 0.8816 - val_loss: 2.1972
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7908 - loss: 5.6554 - val_accuracy: 0.8680 - val_loss: 2.5076
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7830 - loss: 5.7085 - val_accuracy: 0.8816 - val_loss: 2.1322
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7934 - loss: 5.2494 - val_accuracy: 0.8583 - val_loss: 2.4799
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8089 - loss: 6.2938 - val_accuracy: 0.8680 - val_loss: 2.5573
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8206 - loss: 5.2495 - val_accuracy: 0.8680 - val_loss: 3.1508
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8290 - loss: 5.2381 - val_accuracy: 0.8932 - val_loss: 2.7822
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8258 - loss: 5.0337 - val_accuracy: 0.8757 - val_loss: 2.6499
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8005 - loss: 5.9126 - val_accuracy: 0.8854 - val_loss: 2.8415
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8277 - loss: 6.0829 - val_accuracy: 0.8602 - val_loss: 2.4547
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8310 - loss: 5.0585 - val_accuracy: 0.9068 - val_loss: 2.7422
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8446 - loss: 5.0219 - val_accuracy: 0.8893 - val_loss: 3.0963
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8387 - loss: 5.1241 - val_accuracy: 0.8816 - val_loss: 3.1727
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8413 - loss: 5.1596 - val_accuracy: 0.8854 - val_loss: 3.4097
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8310 - loss: 4.8642 - val_accuracy: 0.8951 - val_loss: 3.0813
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8381 - loss: 5.8263 - val_accuracy: 0.8738 - val_loss: 2.4283
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8329 - loss: 5.4160 - val_accuracy: 0.8990 - val_loss: 2.2388
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8459 - loss: 5.0171 - val_accuracy: 0.8835 - val_loss: 3.1048
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8407 - loss: 5.4332 - val_accuracy: 0.8583 - val_loss: 4.3113
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8588 - loss: 5.3624 - val_accuracy: 0.8272 - val_loss: 4.9572
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8543 - loss: 5.1604 - val_accuracy: 0.8680 - val_loss: 3.9103
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8413 - loss: 5.7131 - val_accuracy: 0.8680 - val_loss: 3.7853
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8530 - loss: 4.9901 - val_accuracy: 0.9068 - val_loss: 3.1617
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8653 - loss: 5.0325 - val_accuracy: 0.9029 - val_loss: 3.1954
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8562 - loss: 5.4622 - val_accuracy: 0.9087 - val_loss: 3.2044
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8556 - loss: 5.8415 - val_accuracy: 0.9010 - val_loss: 3.4792
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8426 - loss: 6.2897 - val_accuracy: 0.9087 - val_loss: 3.1167
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8452 - loss: 5.6356 - val_accuracy: 0.8932 - val_loss: 3.3963
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8692 - loss: 5.4101 - val_accuracy: 0.8757 - val_loss: 3.1637
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8756 - loss: 4.7099 - val_accuracy: 0.9146 - val_loss: 2.9253
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8744 - loss: 5.0455 - val_accuracy: 0.8816 - val_loss: 3.2216
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8808 - loss: 4.4172 - val_accuracy: 0.9049 - val_loss: 2.9818
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8731 - loss: 4.5430 - val_accuracy: 0.9068 - val_loss: 2.8016
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8905 - loss: 4.4781 - val_accuracy: 0.9204 - val_loss: 2.9860
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9067 - loss: 3.2399 - val_accuracy: 0.9146 - val_loss: 2.9792
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8951 - loss: 3.7613 - val_accuracy: 0.9184 - val_loss: 3.1303

# %%
# Adapted from "CNNs for Audio Classification" by Papia Nandi, 2021
# Nandi originally adapted from Deep Learning with Python by Francois Chollet, 2018

# Outputs graphs of Losses and Accuracy of model.
history_dict=history.history
loss_values=history_dict['loss']
accuracy_values=history_dict['accuracy']
val_loss_values = history_dict['val_loss']
val_accuracy_values=history_dict['val_accuracy']
epochs=range(1, len(loss_values)+1)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))

ax1.plot(epochs,loss_values,'blue',label='Training Loss')
ax1.plot(epochs,val_loss_values,'red', label='Validation Loss')
ax1.set_title('Losses')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(epochs,accuracy_values,'blue', label='Training accuracy')
ax2.plot(epochs,val_accuracy_values,'red',label='Validation accuracy')
ax2.set_title('Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.tight_layout()
plt.show()

# Print final accuracy and validation accuracy:
print('Final Accuracy: ', accuracy_values[-1])
print('Final Validation Accuracy: ', val_accuracy_values[-1])
# Out:
# Final Accuracy:  0.8950777053833008
# Final Validation Accuracy:  0.9184466004371643

# %%
# Saves model to be used by the prediction Jupyter Notebook
model.save('saved_model/model_last.keras')
